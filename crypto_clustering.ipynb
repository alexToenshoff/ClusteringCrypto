# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"
response = requests.get(url).json()

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
crypto_df = pd.DataFrame(response["Data"]).T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType BuiltOn  \
# 42          0             0            0           0          NaN     NaN
# 300       300             0            0           0        token     ETH
# 365        -1             0            0           0   blockchain     NaN
# 404        -1             0            0           0   blockchain     NaN
# 433       NaN           NaN          NaN         NaN          NaN     NaN
#
#                            SmartContractAddress DecimalPoints Difficulty  \
# 42                                          NaN           NaN        NaN
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557            18        NaN
# 365                                         NaN           NaN        NaN
# 404                                         NaN           NaN        NaN
# 433                                         NaN           NaN        NaN
#
#     AlgorithmType
# 42            NaN
# 300           NaN
# 365           NaN
# 404           NaN
# 433           NaN
#
# [5 rows x 36 columns]

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
# crypto_df = pd.read_csv(file_path, index_col=0)
# crypto_df.head(10)

### Data Preprocessing

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df=crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','MaxSupply']]
crypto_df.head(10)
# Out:
#        CoinName Algorithm IsTrading ProofType TotalCoinsMined MaxSupply
# 42      42 Coin    Scrypt      True   PoW/PoS               0         0
# 300   300 token       N/A      True       N/A             300       300
# 365     365Coin       X11      True   PoW/PoS               0        -1
# 404     404Coin    Scrypt      True   PoW/PoS               0        -1
# 433   433 Token       N/A     False       N/A             NaN       NaN
# 611   SixEleven   SHA-256      True       PoW               0         0
# 808         808   SHA-256      True   PoW/PoS               0         0
# 888    Octocoin       N/A      True       PoW               0         0
# 1337  EliteCoin       X13      True   PoW/PoS               0         0
# 2015  2015 coin       X11      True   PoW/PoS               0         0

# %%
# Keep only cryptocurrencies that are trading
crypto_df=crypto_df[crypto_df["IsTrading"]==True]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (6102, 6)
#          CoinName Algorithm IsTrading ProofType TotalCoinsMined MaxSupply
# 42        42 Coin    Scrypt      True   PoW/PoS               0         0
# 300     300 token       N/A      True       N/A             300       300
# 365       365Coin       X11      True   PoW/PoS               0        -1
# 404       404Coin    Scrypt      True   PoW/PoS               0        -1
# 611     SixEleven   SHA-256      True       PoW               0         0
# 808           808   SHA-256      True   PoW/PoS               0         0
# 888      Octocoin       N/A      True       PoW               0         0
# 1337    EliteCoin       X13      True   PoW/PoS               0         0
# 2015    2015 coin       X11      True   PoW/PoS               0         0
# CRAIG  CraigsCoin       X11      True       PoS             NaN       NaN

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df["Algorithm"] != "N/A"]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1637, 6)
#          CoinName Algorithm IsTrading ProofType TotalCoinsMined MaxSupply
# 42        42 Coin    Scrypt      True   PoW/PoS               0         0
# 365       365Coin       X11      True   PoW/PoS               0        -1
# 404       404Coin    Scrypt      True   PoW/PoS               0        -1
# 611     SixEleven   SHA-256      True       PoW               0         0
# 808           808   SHA-256      True   PoW/PoS               0         0
# 1337    EliteCoin       X13      True   PoW/PoS               0         0
# 2015    2015 coin       X11      True   PoW/PoS               0         0
# CRAIG  CraigsCoin       X11      True       PoS             NaN       NaN
# XBS      Bitstake       X11      True   PoW/PoS             NaN       NaN
# XPY       PayCoin   SHA-256      True       PoS             NaN       NaN

# %%
# Remove the "IsTrading" column
crypto_df.drop("IsTrading", axis=1, inplace=True)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1637, 5)
#          CoinName Algorithm ProofType TotalCoinsMined MaxSupply
# 42        42 Coin    Scrypt   PoW/PoS               0         0
# 365       365Coin       X11   PoW/PoS               0        -1
# 404       404Coin    Scrypt   PoW/PoS               0        -1
# 611     SixEleven   SHA-256       PoW               0         0
# 808           808   SHA-256   PoW/PoS               0         0
# 1337    EliteCoin       X13   PoW/PoS               0         0
# 2015    2015 coin       X11   PoW/PoS               0         0
# CRAIG  CraigsCoin       X11       PoS             NaN       NaN
# XBS      Bitstake       X11   PoW/PoS             NaN       NaN
# XPY       PayCoin   SHA-256       PoS             NaN       NaN

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna(axis=0, how="any")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (690, 5)
#           CoinName Algorithm ProofType TotalCoinsMined   MaxSupply
# 42         42 Coin    Scrypt   PoW/PoS               0           0
# 365        365Coin       X11   PoW/PoS               0          -1
# 404        404Coin    Scrypt   PoW/PoS               0          -1
# 611      SixEleven   SHA-256       PoW               0           0
# 808            808   SHA-256   PoW/PoS               0           0
# 1337     EliteCoin       X13   PoW/PoS               0           0
# 2015     2015 coin       X11   PoW/PoS               0           0
# XPD    PetroDollar  SHA-256D       N/A               0          -1
# ACOIN        ACoin   SHA-256       PoW               0           0
# XMY     MyriadCoin  Multiple       PoW               0  2000000000

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df["TotalCoinsMined"] > 0]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (297, 5)
#                       CoinName Algorithm     ProofType   TotalCoinsMined  \
# NSR                   NuShares       PoS           PoS   6171700777.8311
# TRI             Triangles Coin       X13       PoW/PoS     191617.845172
# CMTC                 CometCoin    Scrypt           PoW            872830
# CHAT                  OpenChat    Scrypt       PoW/PoS        1000000000
# QRL   Quantum Resistant Ledger   RandomX           PoW   75801530.184273
# PURA                      Pura       X11           PoW  188358976.839698
# BTCP           Bitcoin Private  Equihash           PoW    3818878.387802
# ADK               Aidos Kuneen     IMesh           PoW          25000000
# DAPS                 DAPS Coin    Dagger   PoW/PoS/PoA       62319462900
# FOIN                      Foin   SHA-256           N/A     92631000.8161
#
#         MaxSupply
# NSR             0
# TRI             0
# CMTC            0
# CHAT           -1
# QRL     105000000
# PURA           -1
# BTCP     22873588
# ADK             0
# DAPS  70000000000
# FOIN    100000000

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df.iloc[:] != "N/A"].dropna()
crypto_df.head(10)
# Out:
#                       CoinName Algorithm     ProofType   TotalCoinsMined  \
# NSR                   NuShares       PoS           PoS   6171700777.8311
# TRI             Triangles Coin       X13       PoW/PoS     191617.845172
# CMTC                 CometCoin    Scrypt           PoW            872830
# CHAT                  OpenChat    Scrypt       PoW/PoS        1000000000
# QRL   Quantum Resistant Ledger   RandomX           PoW   75801530.184273
# PURA                      Pura       X11           PoW  188358976.839698
# BTCP           Bitcoin Private  Equihash           PoW    3818878.387802
# ADK               Aidos Kuneen     IMesh           PoW          25000000
# DAPS                 DAPS Coin    Dagger   PoW/PoS/PoA       62319462900
# ZANO                      Zano  ProgPowZ       PoW/PoS   13033953.536804
#
#         MaxSupply
# NSR             0
# TRI             0
# CMTC            0
# CHAT           -1
# QRL     105000000
# PURA           -1
# BTCP     22873588
# ADK             0
# DAPS  70000000000
# ZANO           -1

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = pd.DataFrame(crypto_df["CoinName"], index=crypto_df.index)
print(coins_name.shape)
coins_name.head()
# Out:
# (131, 1)
#                       CoinName
# NSR                   NuShares
# TRI             Triangles Coin
# CMTC                 CometCoin
# CHAT                  OpenChat
# QRL   Quantum Resistant Ledger

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop("CoinName", axis=1)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (131, 4)
#      Algorithm     ProofType   TotalCoinsMined    MaxSupply
# NSR        PoS           PoS   6171700777.8311            0
# TRI        X13       PoW/PoS     191617.845172            0
# CMTC    Scrypt           PoW            872830            0
# CHAT    Scrypt       PoW/PoS        1000000000           -1
# QRL    RandomX           PoW   75801530.184273    105000000
# PURA       X11           PoW  188358976.839698           -1
# BTCP  Equihash           PoW    3818878.387802     22873588
# ADK      IMesh           PoW          25000000            0
# DAPS    Dagger   PoW/PoS/PoA       62319462900  70000000000
# ZANO  ProgPowZ       PoW/PoS   13033953.536804           -1

# %%
# Create dummy variables for text features
X = pd.get_dummies(data=crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (131, 80)
#        TotalCoinsMined    MaxSupply  Algorithm_Autolykos  Algorithm_BEP-2  \
# NSR    6171700777.8311            0                    0                0
# TRI      191617.845172            0                    0                0
# CMTC            872830            0                    0                0
# CHAT        1000000000           -1                    0                0
# QRL    75801530.184273    105000000                    0                0
# PURA  188358976.839698           -1                    0                0
# BTCP    3818878.387802     22873588                    0                0
# ADK           25000000            0                    0                0
# DAPS       62319462900  70000000000                    0                0
# ZANO   13033953.536804           -1                    0                0
#
#       Algorithm_BEP-20 Token  Algorithm_BLAKE256  Algorithm_BMW512 / Echo512  \
# NSR                        0                   0                           0
# TRI                        0                   0                           0
# CMTC                       0                   0                           0
# CHAT                       0                   0                           0
# QRL                        0                   0                           0
# PURA                       0                   0                           0
# BTCP                       0                   0                           0
# ADK                        0                   0                           0
# DAPS                       0                   0                           0
# ZANO                       0                   0                           0
#
#       Algorithm_Blake2B + SHA3  Algorithm_Blake2b  Algorithm_C31  ...  \
# NSR                          0                  0              0  ...
# TRI                          0                  0              0  ...
# CMTC                         0                  0              0  ...
# CHAT                         0                  0              0  ...
# QRL                          0                  0              0  ...
# PURA                         0                  0              0  ...
# BTCP                         0                  0              0  ...
# ADK                          0                  0              0  ...
# DAPS                         0                  0              0  ...
# ZANO                         0                  0              0  ...
#
#       ProofType_PoW/PoSe  ProofType_PoW/nPoS  ProofType_ProgPoW/PoS  \
# NSR                    0                   0                      0
# TRI                    0                   0                      0
# CMTC                   0                   0                      0
# CHAT                   0                   0                      0
# QRL                    0                   0                      0
# PURA                   0                   0                      0
# BTCP                   0                   0                      0
# ADK                    0                   0                      0
# DAPS                   0                   0                      0
# ZANO                   0                   0                      0
#
#       ProofType_Proof of Authority  ProofType_Proof-of-Work  ProofType_SPoS  \
# NSR                              0                        0               0
# TRI                              0                        0               0
# CMTC                             0                        0               0
# CHAT                             0                        0               0
# QRL                              0                        0               0
# PURA                             0                        0               0
# BTCP                             0                        0               0
# ADK                              0                        0               0
# DAPS                             0                        0               0
# ZANO                             0                        0               0
#
#       ProofType_TPoS  ProofType_Zero-Knowledge Proof  ProofType_dPoW  \
# NSR                0                               0               0
# TRI                0                               0               0
# CMTC               0                               0               0
# CHAT               0                               0               0
# QRL                0                               0               0
# PURA               0                               0               0
# BTCP               0                               0               0
# ADK                0                               0               0
# DAPS               0                               0               0
# ZANO               0                               0               0
#
#       ProofType_dPoW/PoW
# NSR                    0
# TRI                    0
# CMTC                   0
# CHAT                   0
# QRL                    0
# PURA                   0
# BTCP                   0
# ADK                    0
# DAPS                   0
# ZANO                   0
#
# [10 rows x 80 columns]

# %%
# Standardize data
X = StandardScaler().fit_transform(X)
X[:5]
# Out:
# array([[-0.09640865, -0.09392626, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.12451456, -0.0877058 , -0.0877058 , -0.12451456, -0.12451456,
#         -0.15309311, -0.0877058 , -0.0877058 , -0.23759548, -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.30276504, -0.0877058 ,
#         -0.0877058 , -0.23759548, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.15309311, -0.0877058 , -0.0877058 , -0.12451456,
#          5.01996016, -0.0877058 , -0.0877058 , -0.15309311, -0.12451456,
#         -0.30276504, -0.12451456, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.44926035, -0.0877058 , -0.0877058 , -0.0877058 , -0.1774713 ,
#         -0.0877058 , -0.19920477, -0.12451456, -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.25503069, -0.0877058 ,
#         -0.0877058 , -0.12451456, -0.0877058 , -0.0877058 ,  3.3028913 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.97735555, -0.48564293,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ],
#        [-0.1001422 , -0.09392626, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.12451456, -0.0877058 , -0.0877058 , -0.12451456, -0.12451456,
#         -0.15309311, -0.0877058 , -0.0877058 , -0.23759548, -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.30276504, -0.0877058 ,
#         -0.0877058 , -0.23759548, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.15309311, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.19920477, -0.0877058 , -0.0877058 , -0.15309311, -0.12451456,
#         -0.30276504, -0.12451456, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.44926035, -0.0877058 , -0.0877058 , -0.0877058 , -0.1774713 ,
#         -0.0877058 ,  5.01996016, -0.12451456, -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.25503069, -0.0877058 ,
#         -0.0877058 , -0.12451456, -0.0877058 , -0.0877058 , -0.30276504,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.97735555,  2.05912603,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ],
#        [-0.10014179, -0.09392626, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.12451456, -0.0877058 , -0.0877058 , -0.12451456, -0.12451456,
#         -0.15309311, -0.0877058 , -0.0877058 , -0.23759548, -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.30276504, -0.0877058 ,
#         -0.0877058 , -0.23759548, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.15309311, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.19920477, -0.0877058 , -0.0877058 , -0.15309311, -0.12451456,
#         -0.30276504, -0.12451456, -0.0877058 , -0.0877058 , -0.0877058 ,
#          2.22588083, -0.0877058 , -0.0877058 , -0.0877058 , -0.1774713 ,
#         -0.0877058 , -0.19920477, -0.12451456, -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.25503069, -0.0877058 ,
#         -0.0877058 , -0.12451456, -0.0877058 , -0.0877058 , -0.30276504,
#         -0.0877058 , -0.0877058 , -0.0877058 ,  1.0231691 , -0.48564293,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ],
#        [-0.09953735, -0.09392626, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.12451456, -0.0877058 , -0.0877058 , -0.12451456, -0.12451456,
#         -0.15309311, -0.0877058 , -0.0877058 , -0.23759548, -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.30276504, -0.0877058 ,
#         -0.0877058 , -0.23759548, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.15309311, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.19920477, -0.0877058 , -0.0877058 , -0.15309311, -0.12451456,
#         -0.30276504, -0.12451456, -0.0877058 , -0.0877058 , -0.0877058 ,
#          2.22588083, -0.0877058 , -0.0877058 , -0.0877058 , -0.1774713 ,
#         -0.0877058 , -0.19920477, -0.12451456, -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.25503069, -0.0877058 ,
#         -0.0877058 , -0.12451456, -0.0877058 , -0.0877058 , -0.30276504,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.97735555,  2.05912603,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ],
#        [-0.10009646, -0.09386885, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.12451456, -0.0877058 , -0.0877058 , -0.12451456, -0.12451456,
#         -0.15309311, -0.0877058 , -0.0877058 , -0.23759548, -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.30276504, -0.0877058 ,
#         -0.0877058 , -0.23759548, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.15309311, -0.0877058 , -0.0877058 , -0.12451456,
#         -0.19920477, -0.0877058 , -0.0877058 , -0.15309311,  8.0311892 ,
#         -0.30276504, -0.12451456, -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.44926035, -0.0877058 , -0.0877058 , -0.0877058 , -0.1774713 ,
#         -0.0877058 , -0.19920477, -0.12451456, -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.25503069, -0.0877058 ,
#         -0.0877058 , -0.12451456, -0.0877058 , -0.0877058 , -0.30276504,
#         -0.0877058 , -0.0877058 , -0.0877058 ,  1.0231691 , -0.48564293,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ,
#         -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 , -0.0877058 ]])

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
n_comp = 3
pca = PCA(n_components=n_comp)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# array([[-1.37161435,  0.67728946, -0.71255182],
#        [-1.54657889, -0.75651557, -0.33606363],
#        [ 0.73048319, -0.80611017, -0.24990159],
#        [-0.91167688, -0.94016151, -0.30655066],
#        [ 1.27026124, -0.65250638, -0.16249343],
#        [ 0.48134712, -0.64583219, -0.13510663],
#        [ 1.0764133 , -0.70583714, -0.17045616],
#        [ 0.86476965, -0.57221032, -0.10414605],
#        [-1.52418628,  1.25556972,  6.61469627],
#        [-1.50421282, -0.90698287, -0.27356198],
#        [-1.50407361, -0.90681174, -0.27352216],
#        [ 1.27022455, -0.65254806, -0.16250292],
#        [ 1.27891584, -0.64232797, -0.16015796],
#        [ 0.73069403, -0.80587925, -0.2498521 ],
#        [-1.50421437, -0.9069848 , -0.27356241],
#        [ 2.26122052,  0.66693514,  0.13878937],
#        [-1.61694819,  0.8370511 , -0.78903722],
#        [ 0.88829663, -0.67589394, -0.15809091],
#        [-1.52041703, -0.92026363, -0.277799  ],
#        [ 1.84540354,  0.21748911,  0.03879529],
#        [-1.56944052,  0.82566236,  3.01414925],
#        [ 1.07641466, -0.70583551, -0.1704559 ],
#        [-0.75226827, -0.80819823, -0.21436557],
#        [ 1.84538056,  0.21746421,  0.03878979],
#        [ 1.84538514,  0.21746922,  0.03879086],
#        [-0.53028101, -0.853975  , -0.27574088],
#        [ 0.20300925,  0.08318162, -0.01790891],
#        [ 1.28096765, -0.651923  , -0.1624977 ],
#        [ 1.26351388, -0.64780255, -0.16125779],
#        [ 1.27253513, -0.64919222, -0.1617054 ],
#        [ 1.07647513, -0.70577085, -0.17044107],
#        [-1.60836611,  0.14421108, -0.59331613],
#        [ 1.26346967, -0.64785686, -0.16127045],
#        [-0.53022122, -0.85390125, -0.27572387],
#        [ 1.07643303, -0.70581589, -0.17045138],
#        [ 0.05278398, -0.66034719, -0.11837169],
#        [-0.30339344, -0.40191311,  0.0130869 ],
#        [-0.26409567, -0.60241364, -0.09384545],
#        [-1.58062569,  0.76457813,  2.96207315],
#        [ 1.27642354, -0.63161167, -0.15769716],
#        [ 1.29549884, -0.6304944 , -0.15746723],
#        [ 1.26431281, -0.64682299, -0.1610282 ],
#        [-1.37274053,  0.67605605, -0.71281616],
#        [-0.91187289, -0.94037619, -0.30659667],
#        [-1.37295552,  0.67582052, -0.7128666 ],
#        [-0.26439852, -0.60278595, -0.09393207],
#        [-1.58265717,  1.18848612,  6.63119244],
#        [ 1.26346343, -0.64786469, -0.16127217],
#        [ 1.08291737, -0.6988389 , -0.16887932],
#        [10.13372063,  9.1697457 ,  2.03449522],
#        [-1.82815929,  3.62627164, -2.22153427],
#        [-0.91189441, -0.94039976, -0.30660172],
#        [-0.90520438, -0.93307266, -0.30503144],
#        [ 1.26352721, -0.64778592, -0.16125408],
#        [ 1.26358153, -0.64771901, -0.1612386 ],
#        [ 1.27022787, -0.6525423 , -0.16250151],
#        [ 0.89020949, -0.67383773, -0.15762637],
#        [-0.91148906, -0.93996178, -0.30650418],
#        [ 1.26351434, -0.64780181, -0.16125773],
#        [ 1.28745146, -0.64492056, -0.16093619],
#        [-1.38905158,  1.82462855,  3.83351786],
#        [ 1.2634818 , -0.64784165, -0.16126711],
#        [ 1.84538469,  0.21746872,  0.03879076],
#        [ 1.84538469,  0.21746873,  0.03879076],
#        [-1.54649326, -0.75642305, -0.33604303],
#        [-1.5204757 , -0.92032788, -0.27781277],
#        [ 1.26613383, -0.64457337, -0.16051185],
#        [ 1.26347729, -0.64784756, -0.16126825],
#        [-1.58126335,  0.86448015, -0.7753534 ],
#        [-0.52950568, -0.85300268, -0.275527  ],
#        [-1.51223092, -0.9135474 , -0.27565261],
#        [ 1.28801445, -0.6443305 , -0.16079341],
#        [-1.6169139 ,  0.83708816, -0.78902897],
#        [-0.91176195, -0.9402572 , -0.30656963],
#        [ 0.7305314 , -0.80605736, -0.24989027],
#        [-1.82817609,  3.62625324, -2.22153822],
#        [-1.52046269, -0.92031363, -0.27780972],
#        [-1.60802123,  0.8314418 , -0.78294779],
#        [ 1.27405891, -0.64685991, -0.1612167 ],
#        [ 1.84538031,  0.21746406,  0.03878968],
#        [-1.60804947,  0.83140638, -0.78295558],
#        [-1.16106296, -0.78015749, -0.19181433],
#        [ 0.73049999, -0.80609201, -0.24989755],
#        [-1.82837216,  3.6260385 , -2.22158424],
#        [ 0.05276274, -0.66037384, -0.11837755],
#        [-0.56583229, -0.83998327, -0.22712486],
#        [-1.82836826,  3.62604278, -2.22158332],
#        [ 1.07641622, -0.70583392, -0.17045548],
#        [ 1.84538469,  0.21746873,  0.03879076],
#        [-1.76026974,  3.54599564, -2.15691088],
#        [-0.97367769, -0.03966939, -0.56385305],
#        [-1.5810834 ,  0.76201158,  2.96004129],
#        [ 1.37190286, -0.54791562, -0.13909213],
#        [-1.57417769,  0.80073463,  2.99069708],
#        [ 0.33131983, -0.09049542, -0.39888805],
#        [ 1.07641471, -0.70583559, -0.17045584],
#        [-1.51221161, -0.91352663, -0.27564793],
#        [-1.68788927,  3.22609279, -1.99128759],
#        [-1.82818594,  3.62624245, -2.22154053],
#        [ 0.73048804, -0.80610485, -0.24990045],
#        [ 1.26366859, -0.64761128, -0.16121399],
#        [-1.50403378, -0.90675833, -0.2735126 ],
#        [ 1.07641472, -0.70583557, -0.17045583],
#        [ 0.88827286, -0.67591998, -0.15809649],
#        [ 0.88827425, -0.67591906, -0.15809593],
#        [ 1.26347491, -0.64785054, -0.16126891],
#        [ 0.73054507, -0.80604334, -0.24988668],
#        [-1.58004291,  0.76784601,  2.96466022],
#        [ 1.84568995,  0.21779789,  0.03886449],
#        [-1.58101601,  0.76238946,  2.96034044],
#        [-1.41492654,  4.1230268 , -2.12277978],
#        [-1.54657768, -0.75651424, -0.33606334],
#        [-0.95018823, -0.54479416, -0.04841632],
#        [ 1.29519794, -0.63082396, -0.15753786],
#        [-1.50125444, -0.90327282, -0.27274592],
#        [ 0.75942806, -0.77440899, -0.24310764],
#        [-0.9501517 , -0.54474812, -0.04840633],
#        [ 1.28487888, -0.63500881, -0.15867735],
#        [-1.82840047,  3.6260075 , -2.22159088],
#        [ 1.27023673, -0.6525346 , -0.16250011],
#        [ 0.73093342, -0.80562709, -0.24979189],
#        [-1.72758754,  2.1560685 , -1.49449898],
#        [ 1.2634684 , -0.64785845, -0.1612708 ],
#        [ 0.73050477, -0.80608653, -0.24989652],
#        [-1.59469489,  1.14817723,  6.58887191],
#        [ 0.73051477, -0.80607608, -0.24989398],
#        [ 0.73050141, -0.8060902 , -0.24989731],
#        [-1.5465631 , -0.75649828, -0.33605992],
#        [-1.58104119,  0.76223552,  2.96024758],
#        [-0.91189386, -0.94039916, -0.30660159],
#        [-1.20239201,  0.52754001, -0.57064378]])

# %%
# Create a DataFrame with the principal components data
col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
pcs_df = pd.DataFrame(principal_components, columns=col_names, index=crypto_df.index)
print(pcs_df.shape)
pcs_df.head(10)
# Out:
# (131, 3)
#           PC 1      PC 2      PC 3
# NSR  -1.371614  0.677289 -0.712552
# TRI  -1.546579 -0.756516 -0.336064
# CMTC  0.730483 -0.806110 -0.249902
# CHAT -0.911677 -0.940162 -0.306551
# QRL   1.270261 -0.652506 -0.162493
# PURA  0.481347 -0.645832 -0.135107
# BTCP  1.076413 -0.705837 -0.170456
# ADK   0.864770 -0.572210 -0.104146
# DAPS -1.524186  1.255570  6.614696
# ZANO -1.504213 -0.906983 -0.273562

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# C:\Users\AlexToenshoff\anaconda3\envs\algotrading\lib\site-packages\sklearn\cluster\_kmeans.py:1040: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   "KMeans is known to have a memory leak on Windows "
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([crypto_df, pcs_df], axis=1, sort=False)
clustered_df["CoinName"] = coins_name["CoinName"]
clustered_df["Class"] = model.labels_
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# (131, 9)
#      Algorithm     ProofType   TotalCoinsMined    MaxSupply      PC 1  \
# NSR        PoS           PoS   6171700777.8311            0 -1.371614
# TRI        X13       PoW/PoS     191617.845172            0 -1.546579
# CMTC    Scrypt           PoW            872830            0  0.730483
# CHAT    Scrypt       PoW/PoS        1000000000           -1 -0.911677
# QRL    RandomX           PoW   75801530.184273    105000000  1.270261
# PURA       X11           PoW  188358976.839698           -1  0.481347
# BTCP  Equihash           PoW    3818878.387802     22873588  1.076413
# ADK      IMesh           PoW          25000000            0  0.864770
# DAPS    Dagger   PoW/PoS/PoA       62319462900  70000000000 -1.524186
# ZANO  ProgPowZ       PoW/PoS   13033953.536804           -1 -1.504213
#
#           PC 2      PC 3                  CoinName  Class
# NSR   0.677289 -0.712552                  NuShares      1
# TRI  -0.756516 -0.336064            Triangles Coin      0
# CMTC -0.806110 -0.249902                 CometCoin      0
# CHAT -0.940162 -0.306551                  OpenChat      0
# QRL  -0.652506 -0.162493  Quantum Resistant Ledger      0
# PURA -0.645832 -0.135107                      Pura      0
# BTCP -0.705837 -0.170456           Bitcoin Private      0
# ADK  -0.572210 -0.104146              Aidos Kuneen      0
# DAPS  1.255570  6.614696                 DAPS Coin      3
# ZANO -0.906983 -0.273562                      Zano      0

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
mm_scaler = MinMaxScaler()
plot_data = mm_scaler.fit_transform(
    clustered_df[["MaxSupply", "TotalCoinsMined"]]
)
plot_df = pd.DataFrame(
    plot_data, columns=["MaxSupply", "TotalCoinsMined"], index=clustered_df.index
)
plot_df["CoinName"] = clustered_df["CoinName"]
plot_df["Class"] = clustered_df["Class"]
plot_df.head()
# Out:
#          MaxSupply  TotalCoinsMined                  CoinName  Class
# NSR   4.761905e-14     3.255124e-04                  NuShares      1
# TRI   4.761905e-14     9.975880e-09            Triangles Coin      0
# CMTC  4.761905e-14     4.590489e-08                 CometCoin      0
# CHAT  0.000000e+00     5.274264e-05                  OpenChat      0
# QRL   5.000000e-06     3.997852e-06  Quantum Resistant Ledger      0

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
plot_df.hvplot.scatter(
    x="TotalCoinsMined", y="MaxSupply", hover_cols=["CoinName"], by="Class"
)
# Out:
# :NdOverlay   [Class]
#    :Scatter   [TotalCoinsMined]   (MaxSupply,CoinName)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
# Table with tradable cryptos
clustered_df[
    [
        "CoinName",
        "Algorithm",
        "ProofType",
        "MaxSupply",
        "TotalCoinsMined",
        "Class",
    ]
].hvplot.table()
# Out:
# :Table   [CoinName,Algorithm,ProofType,MaxSupply,TotalCoinsMined,Class]

# %%
# Print the total number of tradable cryptocurrencies
print(f"There are {clustered_df.shape[0]} tradable cryptocurrencies.")
# Out:
# There are 131 tradable cryptocurrencies.
